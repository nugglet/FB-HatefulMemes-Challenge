# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

import torch

from utils import preprocessing

# %matplotlib inline

# %%
loaders_dict, datasets_dict = preprocessing.load_data()
print(loaders_dict.keys(), datasets_dict.keys())
# Out:
# dict_keys(['dev_seen', 'dev_unseen', 'test_seen', 'test_unseen', 'train']) dict_keys(['dev_seen', 'dev_unseen', 'test_seen', 'test_unseen', 'train'])

# %%
train_set = datasets_dict['train']
preprocessing.img_grid(train_set, num_imgs=20, rows=4)
